# %% [markdown]
# # **GROUP PROJECT - ETL (WEB SCRAPPING)**

# %% [markdown]
# GROUP MEMBER
#
# 1. ISKANDAR HAZRYLL BIN NAZRIZAL (A188532)
# 2. MUHAMMAD HAFIEZ BIN ABU HASSAN (A187291)
# 3. NUR AMIRA NADIA BINTI AHLAN (A187911)
# 4. NURULAMIRA BINTI MOHD MISRAN (A188250)

# %% [markdown]
# ### **1. INSTALL BEAUTIFUL SOUP**

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %% [markdown]
# ## **2. IMPORT LIBRARIES THAT ARE REQUIRED**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from PIL import Image
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %% [markdown]
# ## **3. EXTRACT DATA FROM WEBSITE**

# %%
base_url = "https://www.etsy.com/c/shoes?ref=pagination&page="

# Set the range of pages you want to scrape (up to page 50)
start_page = 1
end_page = 20

# Loop through the pages
for page_number in range(start_page, end_page + 1):
    # Construct the URL for the current page
    current_url = f"{base_url}{page_number}"

    # Send an HTTP GET request to the URL
    response = requests.get(current_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the pagination links for the next iteration
        pagination_links = soup.select('ul.wt-action-group a[data-page]')

        # Extract and print the unique links in sequential order
        unique_links = set()
        for link in pagination_links:
            next_page_number = link.get('data-page')
            next_page_url = link.get('href')
            unique_links.add((next_page_number, next_page_url))

        # Sort the unique links by page number
        sorted_links = sorted(unique_links, key=lambda x: int(x[0]))

        # Print the sorted links for verification
        for next_page_number, next_page_url in sorted_links:
            print(f"Next Page {next_page_number}: {next_page_url}")
# Out:
# Next Page 1: https://www.etsy.com/c/shoes?ref=pagination&page=1
# Next Page 3: https://www.etsy.com/c/shoes?ref=pagination&page=3
# Next Page 4: https://www.etsy.com/c/shoes?ref=pagination&page=4
# Next Page 5: https://www.etsy.com/c/shoes?ref=pagination&page=5
# Next Page 6: https://www.etsy.com/c/shoes?ref=pagination&page=6
# Next Page 7: https://www.etsy.com/c/shoes?ref=pagination&page=7
# Next Page 8: https://www.etsy.com/c/shoes?ref=pagination&page=8
# Next Page 1: https://www.etsy.com/c/shoes?ref=pagination&page=1
# Next Page 2: https://www.etsy.com/c/shoes?ref=pagination&page=2
# Next Page 4: https://www.etsy.com/c/shoes?ref=pagination&page=4
# Next Page 5: https://www.etsy.com/c/shoes?ref=pagination&page=5
# Next Page 6: https://www.etsy.com/c/shoes?ref=pagination&page=6
# Next Page 7: https://www.etsy.com/c/shoes?ref=pagination&page=7
# Next Page 8: https://www.etsy.com/c/shoes?ref=pagination&page=8
# Next Page 2: https://www.etsy.com/c/shoes?ref=pagination&page=2
# Next Page 3: https://www.etsy.com/c/shoes?ref=pagination&page=3
# Next Page 4: https://www.etsy.com/c/shoes?ref=pagination&page=4
# Next Page 6: https://www.etsy.com/c/shoes?ref=pagination&page=6
# Next Page 7: https://www.etsy.com/c/shoes?ref=pagination&page=7
# Next Page 8: https://www.etsy.com/c/shoes?ref=pagination&page=8
# Next Page 6: https://www.etsy.com/c/shoes?ref=pagination&page=6
# Next Page 7: https://www.etsy.com/c/shoes?ref=pagination&page=7
# Next Page 8: https://www.etsy.com/c/shoes?ref=pagination&page=8
# Next Page 10: https://www.etsy.com/c/shoes?ref=pagination&page=10
# Next Page 11: https://www.etsy.com/c/shoes?ref=pagination&page=11
# Next Page 12: https://www.etsy.com/c/shoes?ref=pagination&page=12
# Next Page 7: https://www.etsy.com/c/shoes?ref=pagination&page=7
# Next Page 8: https://www.etsy.com/c/shoes?ref=pagination&page=8
# Next Page 9: https://www.etsy.com/c/shoes?ref=pagination&page=9
# Next Page 11: https://www.etsy.com/c/shoes?ref=pagination&page=11
# Next Page 12: https://www.etsy.com/c/shoes?ref=pagination&page=12
# Next Page 13: https://www.etsy.com/c/shoes?ref=pagination&page=13
# Next Page 8: https://www.etsy.com/c/shoes?ref=pagination&page=8
# Next Page 9: https://www.etsy.com/c/shoes?ref=pagination&page=9
# Next Page 10: https://www.etsy.com/c/shoes?ref=pagination&page=10
# Next Page 12: https://www.etsy.com/c/shoes?ref=pagination&page=12
# Next Page 13: https://www.etsy.com/c/shoes?ref=pagination&page=13
# Next Page 14: https://www.etsy.com/c/shoes?ref=pagination&page=14
# Next Page 9: https://www.etsy.com/c/shoes?ref=pagination&page=9
# Next Page 10: https://www.etsy.com/c/shoes?ref=pagination&page=10
# Next Page 11: https://www.etsy.com/c/shoes?ref=pagination&page=11
# Next Page 13: https://www.etsy.com/c/shoes?ref=pagination&page=13
# Next Page 14: https://www.etsy.com/c/shoes?ref=pagination&page=14
# Next Page 15: https://www.etsy.com/c/shoes?ref=pagination&page=15
# Next Page 10: https://www.etsy.com/c/shoes?ref=pagination&page=10
# Next Page 11: https://www.etsy.com/c/shoes?ref=pagination&page=11
# Next Page 12: https://www.etsy.com/c/shoes?ref=pagination&page=12
# Next Page 14: https://www.etsy.com/c/shoes?ref=pagination&page=14
# Next Page 15: https://www.etsy.com/c/shoes?ref=pagination&page=15
# Next Page 16: https://www.etsy.com/c/shoes?ref=pagination&page=16
# Next Page 11: https://www.etsy.com/c/shoes?ref=pagination&page=11
# Next Page 12: https://www.etsy.com/c/shoes?ref=pagination&page=12
# Next Page 13: https://www.etsy.com/c/shoes?ref=pagination&page=13
# Next Page 15: https://www.etsy.com/c/shoes?ref=pagination&page=15
# Next Page 16: https://www.etsy.com/c/shoes?ref=pagination&page=16
# Next Page 17: https://www.etsy.com/c/shoes?ref=pagination&page=17
# Next Page 13: https://www.etsy.com/c/shoes?ref=pagination&page=13
# Next Page 14: https://www.etsy.com/c/shoes?ref=pagination&page=14
# Next Page 15: https://www.etsy.com/c/shoes?ref=pagination&page=15
# Next Page 17: https://www.etsy.com/c/shoes?ref=pagination&page=17
# Next Page 18: https://www.etsy.com/c/shoes?ref=pagination&page=18
# Next Page 19: https://www.etsy.com/c/shoes?ref=pagination&page=19
# Next Page 14: https://www.etsy.com/c/shoes?ref=pagination&page=14
# Next Page 15: https://www.etsy.com/c/shoes?ref=pagination&page=15
# Next Page 16: https://www.etsy.com/c/shoes?ref=pagination&page=16
# Next Page 18: https://www.etsy.com/c/shoes?ref=pagination&page=18
# Next Page 19: https://www.etsy.com/c/shoes?ref=pagination&page=19
# Next Page 20: https://www.etsy.com/c/shoes?ref=pagination&page=20
# Next Page 16: https://www.etsy.com/c/shoes?ref=pagination&page=16
# Next Page 17: https://www.etsy.com/c/shoes?ref=pagination&page=17
# Next Page 18: https://www.etsy.com/c/shoes?ref=pagination&page=18
# Next Page 20: https://www.etsy.com/c/shoes?ref=pagination&page=20
# Next Page 21: https://www.etsy.com/c/shoes?ref=pagination&page=21
# Next Page 22: https://www.etsy.com/c/shoes?ref=pagination&page=22
# Next Page 17: https://www.etsy.com/c/shoes?ref=pagination&page=17
# Next Page 18: https://www.etsy.com/c/shoes?ref=pagination&page=18
# Next Page 19: https://www.etsy.com/c/shoes?ref=pagination&page=19
# Next Page 21: https://www.etsy.com/c/shoes?ref=pagination&page=21
# Next Page 22: https://www.etsy.com/c/shoes?ref=pagination&page=22
# Next Page 23: https://www.etsy.com/c/shoes?ref=pagination&page=23

# %%
# Static exchange rate
usd_to_myr_exchange_rate = 4.59

# %%
def extract_product_info(container, usd_to_myr_exchange_rate):
    product_info = {}

    # Extracting shop ID
    shop_id_tag = container.find("div", {'data-shop-id': True})
    product_info['Shop ID'] = shop_id_tag['data-shop-id'] if shop_id_tag else None

    # Extracting product names
    names = container.find("h3", class_="wt-text-caption")
    product_info['Name'] = names.text.strip() if names else None

    # Extracting prices
    prices = container.find("span", class_="currency-value")
    product_info['Price'] = prices.text if prices else None

    # Extracting original prices
    oriprice = container.find("span", class_="wt-text-strikethrough")
    original_price_str = oriprice.text.strip() if oriprice else None
    product_info['OriginalPrice'] = convert_currency(original_price_str, usd_to_myr_exchange_rate) if original_price_str else None

    # Extracting number of reviews
    reviews = container.find("span", class_="wt-text-caption wt-text-gray wt-display-inline-block wt-nudge-l-3 wt-pr-xs-1")
    product_info['NumberOfReviews'] = reviews.text.strip().replace('(', '').replace(')', '') if reviews else None

    # Extracting product shipping status
    ship = container.find("span", class_="wt-badge wt-badge--small wt-badge--statusValue")
    product_info['ShipStatus'] = ship.text.strip() if ship else None

    # Extracting product star seller
    starseller = container.find("p", class_="wt-text-caption-title wt-nudge-l-2 star-seller-badge-lavender-text-light")
    product_info['StarSeller'] = starseller.text.strip() if starseller else None

    # Extracting product recommended
    rec = container.find("span", class_="wt-badge wt-badge--statusRecommendation wt-badge--small wt-mb-xs-1")
    product_info['Recommended'] = rec.text.strip() if rec else None

     # Extracting product rating
    rating_tag = container.find('input', {'name': 'rating'})
    product_info['Rating'] = rating_tag['value'] if rating_tag else None

    return product_info

def extract_products_from_page(page_url):
    products = []

    # Send an HTTP GET request to the URL
    response = requests.get(page_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all product containers
        product_containers = soup.find_all("div", class_="wt-height-full")

        for container in product_containers:
            product_info = extract_product_info(container,usd_to_myr_exchange_rate)
            products.append(product_info)

    return products


def convert_currency(amount, exchange_rate):
    try:
        amount_in_usd = float(amount.replace('$', '').replace(',', ''))
        amount_in_myr = amount_in_usd * exchange_rate
        return f'{amount_in_myr:.2f}'
    except ValueError:
        return None

base_url = "https://www.etsy.com/c/shoes?ref=pagination&page="

# Set the range of pages you want to scrape (up to page 20)
start_page = 1
end_page = 20

# Extract products for each page and store in a list
all_products = []

# Loop through the pages
for page_number in range(start_page, end_page + 1):
    # Construct the URL for the current page
    current_url = f"{base_url}{page_number}"

    # Extract products from the current page
    products_on_page = extract_products_from_page(current_url)
    all_products.extend(products_on_page)

# %%
    # Create a DataFrame from the list of products
    df = pd.DataFrame(all_products)

    # Print the DataFrame
    df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None    None
# 1        None                                               None    None
# 2        None                                               None    None
# 3        None                                               None    None
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None    None
#
#     OriginalPrice NumberOfReviews     ShipStatus   StarSeller  Recommended  \
# 0            None            None           None         None         None
# 1            None            None           None         None         None
# 2            None            None           None         None         None
# 3            None            None           None         None         None
# 4          550.80           2,419  FREE shipping  Star Seller         None
# ..            ...             ...            ...          ...          ...
# 563        633.42           1,868           None  Star Seller         None
# 564          None           3,453  FREE shipping         None  Etsy’s Pick
# 565          None           1,267           None  Star Seller  Etsy’s Pick
# 566          None          16,867  FREE shipping  Star Seller  Etsy’s Pick
# 567          None            None           None         None         None
#
#      Rating
# 0      None
# 1         5
# 2         5
# 3         5
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567    None
#
# [568 rows x 9 columns]

# %% [markdown]
# ## **5. SAVE DATA TO CSV.FILE**

# %%
# Save to CSV
df.to_csv("shoes_etsy.csv", index=False)

# %% [markdown]
# ## **6. PERFORM DATA CLEANING ON THE DATA**

# %%
# import data
#df = pd.read_csv('shoes_etsy.csv')
#df

# %%
# Check for presences of null value before data cleaning
df.isna().any()
# Out:
# Shop ID            True
# Name               True
# Price              True
# OriginalPrice      True
# NumberOfReviews    True
# ShipStatus         True
# StarSeller         True
# Recommended        True
# Rating             True
# dtype: bool

# %%
# Check data types for each column before data cleaning
df.dtypes
# Out:
# Shop ID            object
# Name               object
# Price              object
# OriginalPrice      object
# NumberOfReviews    object
# ShipStatus         object
# StarSeller         object
# Recommended        object
# Rating             object
# dtype: object

# %%
# Convert data types
df['Shop ID'] = df['Shop ID'].astype(str)
df['Name'] = df['Name'].astype(str)
df['Price'] = pd.to_numeric(df['Price'], errors='coerce').astype(float)
df['OriginalPrice'] = pd.to_numeric(df['OriginalPrice'], errors='coerce').astype(float)
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce').astype(float)

# Display the updated DataFrame
df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice NumberOfReviews     ShipStatus   StarSeller  Recommended  \
# 0              NaN            None           None         None         None
# 1              NaN            None           None         None         None
# 2              NaN            None           None         None         None
# 3              NaN            None           None         None         None
# 4           550.80           2,419  FREE shipping  Star Seller         None
# ..             ...             ...            ...          ...          ...
# 563         633.42           1,868           None  Star Seller         None
# 564            NaN           3,453  FREE shipping         None  Etsy’s Pick
# 565            NaN           1,267           None  Star Seller  Etsy’s Pick
# 566            NaN          16,867  FREE shipping  Star Seller  Etsy’s Pick
# 567            NaN            None           None         None         None
#
#      Rating
# 0       NaN
# 1    5.0000
# 2    5.0000
# 3    5.0000
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567     NaN
#
# [568 rows x 9 columns]

# %%
# Check data types for each column after change the data type
df.dtypes
# Out:
# Shop ID             object
# Name                object
# Price              float64
# OriginalPrice      float64
# NumberOfReviews     object
# ShipStatus          object
# StarSeller          object
# Recommended         object
# Rating             float64
# dtype: object

# %%
df.to_csv("shoes_etsy_2.csv", index = False)

# %% [markdown]
# ## **7. PERFORM MORE DATA CLEANING**

# %%
# import data
df = pd.read_csv('shoes_etsy_2.csv')

# %% [markdown]
# ### **NAME**

# %%
# Clean the product name
product_name_clean = re.sub(r'\W+', ' ', 'Name') # Replace all non-alphabetic characters with spaces
product_name_clean = product_name_clean.lower() # Convert the string to lowercase
product_name_clean = product_name_clean.title() # Capitalize the first letter of each word

# %%
df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice NumberOfReviews     ShipStatus   StarSeller  Recommended  \
# 0              NaN             NaN            NaN          NaN          NaN
# 1              NaN             NaN            NaN          NaN          NaN
# 2              NaN             NaN            NaN          NaN          NaN
# 3              NaN             NaN            NaN          NaN          NaN
# 4           550.80           2,419  FREE shipping  Star Seller          NaN
# ..             ...             ...            ...          ...          ...
# 563         633.42           1,868            NaN  Star Seller          NaN
# 564            NaN           3,453  FREE shipping          NaN  Etsy’s Pick
# 565            NaN           1,267            NaN  Star Seller  Etsy’s Pick
# 566            NaN          16,867  FREE shipping  Star Seller  Etsy’s Pick
# 567            NaN             NaN            NaN          NaN          NaN
#
#      Rating
# 0       NaN
# 1    5.0000
# 2    5.0000
# 3    5.0000
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567     NaN
#
# [568 rows x 9 columns]

# %% [markdown]
# ### **PRICE (RM)**

# %%
# Round off decimals in prices into 2 decimal places
df['Price'] = df['Price'].round(decimals=2)

df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice NumberOfReviews     ShipStatus   StarSeller  Recommended  \
# 0              NaN             NaN            NaN          NaN          NaN
# 1              NaN             NaN            NaN          NaN          NaN
# 2              NaN             NaN            NaN          NaN          NaN
# 3              NaN             NaN            NaN          NaN          NaN
# 4           550.80           2,419  FREE shipping  Star Seller          NaN
# ..             ...             ...            ...          ...          ...
# 563         633.42           1,868            NaN  Star Seller          NaN
# 564            NaN           3,453  FREE shipping          NaN  Etsy’s Pick
# 565            NaN           1,267            NaN  Star Seller  Etsy’s Pick
# 566            NaN          16,867  FREE shipping  Star Seller  Etsy’s Pick
# 567            NaN             NaN            NaN          NaN          NaN
#
#      Rating
# 0       NaN
# 1    5.0000
# 2    5.0000
# 3    5.0000
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567     NaN
#
# [568 rows x 9 columns]

# %% [markdown]
# ### **ORIGINAL PRICE (RM)**

# %%
# Assuming df is your DataFrame
df['OriginalPrice'] = pd.to_numeric(df['OriginalPrice'], errors='coerce')  # Convert to numeric, coerce errors to NaN

# Round off decimals in OriginalPrices into 2 decimal places
df['OriginalPrice'] = df['OriginalPrice'].round(decimals=2)

df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice NumberOfReviews     ShipStatus   StarSeller  Recommended  \
# 0              NaN             NaN            NaN          NaN          NaN
# 1              NaN             NaN            NaN          NaN          NaN
# 2              NaN             NaN            NaN          NaN          NaN
# 3              NaN             NaN            NaN          NaN          NaN
# 4           550.80           2,419  FREE shipping  Star Seller          NaN
# ..             ...             ...            ...          ...          ...
# 563         633.42           1,868            NaN  Star Seller          NaN
# 564            NaN           3,453  FREE shipping          NaN  Etsy’s Pick
# 565            NaN           1,267            NaN  Star Seller  Etsy’s Pick
# 566            NaN          16,867  FREE shipping  Star Seller  Etsy’s Pick
# 567            NaN             NaN            NaN          NaN          NaN
#
#      Rating
# 0       NaN
# 1    5.0000
# 2    5.0000
# 3    5.0000
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567     NaN
#
# [568 rows x 9 columns]

# %%
# replace missing values in OriginalPrice with corresponding values from Price
df['OriginalPrice'] = df.apply(lambda row: row['Price'] if pd.isna(row['OriginalPrice']) else row['OriginalPrice'], axis=1)

df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice NumberOfReviews     ShipStatus   StarSeller  Recommended  \
# 0              NaN             NaN            NaN          NaN          NaN
# 1              NaN             NaN            NaN          NaN          NaN
# 2              NaN             NaN            NaN          NaN          NaN
# 3              NaN             NaN            NaN          NaN          NaN
# 4           550.80           2,419  FREE shipping  Star Seller          NaN
# ..             ...             ...            ...          ...          ...
# 563         633.42           1,868            NaN  Star Seller          NaN
# 564          52.22           3,453  FREE shipping          NaN  Etsy’s Pick
# 565          21.57           1,267            NaN  Star Seller  Etsy’s Pick
# 566          55.00          16,867  FREE shipping  Star Seller  Etsy’s Pick
# 567            NaN             NaN            NaN          NaN          NaN
#
#      Rating
# 0       NaN
# 1    5.0000
# 2    5.0000
# 3    5.0000
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567     NaN
#
# [568 rows x 9 columns]

# %% [markdown]
# ### **NUMBER OF REVIEWS**

# %%
# Remove commas from 'NumberOfReviews'
df['NumberOfReviews'] = df['NumberOfReviews'].astype(str).str.replace(',', '')

# Convert 'NumberOfReviews' to int
df['NumberOfReviews'] = pd.to_numeric(df['NumberOfReviews'], errors='coerce').astype('Int64')

# Display the updated DataFrame
df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice  NumberOfReviews     ShipStatus   StarSeller  Recommended  \
# 0              NaN             <NA>            NaN          NaN          NaN
# 1              NaN             <NA>            NaN          NaN          NaN
# 2              NaN             <NA>            NaN          NaN          NaN
# 3              NaN             <NA>            NaN          NaN          NaN
# 4           550.80             2419  FREE shipping  Star Seller          NaN
# ..             ...              ...            ...          ...          ...
# 563         633.42             1868            NaN  Star Seller          NaN
# 564          52.22             3453  FREE shipping          NaN  Etsy’s Pick
# 565          21.57             1267            NaN  Star Seller  Etsy’s Pick
# 566          55.00            16867  FREE shipping  Star Seller  Etsy’s Pick
# 567            NaN             <NA>            NaN          NaN          NaN
#
#      Rating
# 0       NaN
# 1    5.0000
# 2    5.0000
# 3    5.0000
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567     NaN
#
# [568 rows x 9 columns]

# %% [markdown]
# ### **SHIPPING STATUS**

# %%
ship_value = 'PAID Shipping'
df['ShipStatus'] = df['ShipStatus'].fillna(ship_value)

df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice  NumberOfReviews     ShipStatus   StarSeller  Recommended  \
# 0              NaN             <NA>  PAID Shipping          NaN          NaN
# 1              NaN             <NA>  PAID Shipping          NaN          NaN
# 2              NaN             <NA>  PAID Shipping          NaN          NaN
# 3              NaN             <NA>  PAID Shipping          NaN          NaN
# 4           550.80             2419  FREE shipping  Star Seller          NaN
# ..             ...              ...            ...          ...          ...
# 563         633.42             1868  PAID Shipping  Star Seller          NaN
# 564          52.22             3453  FREE shipping          NaN  Etsy’s Pick
# 565          21.57             1267  PAID Shipping  Star Seller  Etsy’s Pick
# 566          55.00            16867  FREE shipping  Star Seller  Etsy’s Pick
# 567            NaN             <NA>  PAID Shipping          NaN          NaN
#
#      Rating
# 0       NaN
# 1    5.0000
# 2    5.0000
# 3    5.0000
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567     NaN
#
# [568 rows x 9 columns]

# %%
# Assuming df is your DataFrame
df['ShipStatus'] = df['ShipStatus'].apply(lambda x: re.sub(r'\W+', ' ', str(x)).lower().title())

# Print the DataFrame
df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice  NumberOfReviews     ShipStatus   StarSeller  Recommended  \
# 0              NaN             <NA>  Paid Shipping          NaN          NaN
# 1              NaN             <NA>  Paid Shipping          NaN          NaN
# 2              NaN             <NA>  Paid Shipping          NaN          NaN
# 3              NaN             <NA>  Paid Shipping          NaN          NaN
# 4           550.80             2419  Free Shipping  Star Seller          NaN
# ..             ...              ...            ...          ...          ...
# 563         633.42             1868  Paid Shipping  Star Seller          NaN
# 564          52.22             3453  Free Shipping          NaN  Etsy’s Pick
# 565          21.57             1267  Paid Shipping  Star Seller  Etsy’s Pick
# 566          55.00            16867  Free Shipping  Star Seller  Etsy’s Pick
# 567            NaN             <NA>  Paid Shipping          NaN          NaN
#
#      Rating
# 0       NaN
# 1    5.0000
# 2    5.0000
# 3    5.0000
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567     NaN
#
# [568 rows x 9 columns]

# %% [markdown]
# ### **RANK SELLER**

# %%
seller_value = 'Basic Seller'
df['StarSeller'] = df['StarSeller'].fillna(seller_value)

df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice  NumberOfReviews     ShipStatus    StarSeller  Recommended  \
# 0              NaN             <NA>  Paid Shipping  Basic Seller          NaN
# 1              NaN             <NA>  Paid Shipping  Basic Seller          NaN
# 2              NaN             <NA>  Paid Shipping  Basic Seller          NaN
# 3              NaN             <NA>  Paid Shipping  Basic Seller          NaN
# 4           550.80             2419  Free Shipping   Star Seller          NaN
# ..             ...              ...            ...           ...          ...
# 563         633.42             1868  Paid Shipping   Star Seller          NaN
# 564          52.22             3453  Free Shipping  Basic Seller  Etsy’s Pick
# 565          21.57             1267  Paid Shipping   Star Seller  Etsy’s Pick
# 566          55.00            16867  Free Shipping   Star Seller  Etsy’s Pick
# 567            NaN             <NA>  Paid Shipping  Basic Seller          NaN
#
#      Rating
# 0       NaN
# 1    5.0000
# 2    5.0000
# 3    5.0000
# 4    4.8717
# ..      ...
# 563  4.8533
# 564  4.9076
# 565  4.9592
# 566  4.8323
# 567     NaN
#
# [568 rows x 9 columns]

# %% [markdown]
# ### **RECOMMENDED**

# %%
rec_value = 'Not Recommended'
df['Recommended'] = df['Recommended'].fillna(rec_value)

# Assuming df is your DataFrame
df['Recommended'] = df['Recommended'].replace({"Etsy’s Pick": "Recommended"})

df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice  NumberOfReviews     ShipStatus    StarSeller  \
# 0              NaN             <NA>  Paid Shipping  Basic Seller
# 1              NaN             <NA>  Paid Shipping  Basic Seller
# 2              NaN             <NA>  Paid Shipping  Basic Seller
# 3              NaN             <NA>  Paid Shipping  Basic Seller
# 4           550.80             2419  Free Shipping   Star Seller
# ..             ...              ...            ...           ...
# 563         633.42             1868  Paid Shipping   Star Seller
# 564          52.22             3453  Free Shipping  Basic Seller
# 565          21.57             1267  Paid Shipping   Star Seller
# 566          55.00            16867  Free Shipping   Star Seller
# 567            NaN             <NA>  Paid Shipping  Basic Seller
#
#          Recommended  Rating
# 0    Not Recommended     NaN
# 1    Not Recommended  5.0000
# 2    Not Recommended  5.0000
# 3    Not Recommended  5.0000
# 4    Not Recommended  4.8717
# ..               ...     ...
# 563  Not Recommended  4.8533
# 564      Recommended  4.9076
# 565      Recommended  4.9592
# 566      Recommended  4.8323
# 567  Not Recommended     NaN
#
# [568 rows x 9 columns]

# %% [markdown]
# ### **RATING**

# %%
# Assuming df is your DataFrame
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')  # Convert to numeric, coerce errors to NaN

# Round off decimals in ratings into 2 decimal places
df['Rating'] = df['Rating'].round(decimals=2)

df
# Out:
#       Shop ID                                               Name   Price  \
# 0        None                                               None     NaN
# 1        None                                               None     NaN
# 2        None                                               None     NaN
# 3        None                                               None     NaN
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# ..        ...                                                ...     ...
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
# 567      None                                               None     NaN
#
#      OriginalPrice  NumberOfReviews     ShipStatus    StarSeller  \
# 0              NaN             <NA>  Paid Shipping  Basic Seller
# 1              NaN             <NA>  Paid Shipping  Basic Seller
# 2              NaN             <NA>  Paid Shipping  Basic Seller
# 3              NaN             <NA>  Paid Shipping  Basic Seller
# 4           550.80             2419  Free Shipping   Star Seller
# ..             ...              ...            ...           ...
# 563         633.42             1868  Paid Shipping   Star Seller
# 564          52.22             3453  Free Shipping  Basic Seller
# 565          21.57             1267  Paid Shipping   Star Seller
# 566          55.00            16867  Free Shipping   Star Seller
# 567            NaN             <NA>  Paid Shipping  Basic Seller
#
#          Recommended  Rating
# 0    Not Recommended     NaN
# 1    Not Recommended    5.00
# 2    Not Recommended    5.00
# 3    Not Recommended    5.00
# 4    Not Recommended    4.87
# ..               ...     ...
# 563  Not Recommended    4.85
# 564      Recommended    4.91
# 565      Recommended    4.96
# 566      Recommended    4.83
# 567  Not Recommended     NaN
#
# [568 rows x 9 columns]

# %%
# Drop rows with NaN values in any columns
df = df.dropna()

df
# Out:
#       Shop ID                                               Name   Price  \
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# 5    16050399  Historic eighteenth century shoes, 18th centur...  170.28
# 6    34365344  Barefoot Women Boot | Brown Leather Boot | Ear...  110.50
# 7     5774162                     Women's Middle English - OLIVE  216.00
# 8    34365344  Earth Shoe | Barefoot Sandale Women | Sandals ...   78.00
# ..        ...                                                ...     ...
# 562  22321483  Baby crawling shoes Mocca Leo dark blue with l...   45.41
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
#
#      OriginalPrice  NumberOfReviews     ShipStatus    StarSeller  \
# 4           550.80             2419  Free Shipping   Star Seller
# 5           170.28             1031  Paid Shipping   Star Seller
# 6           780.30             2419  Free Shipping   Star Seller
# 7           216.00              533  Free Shipping  Basic Seller
# 8           550.80             2419  Free Shipping   Star Seller
# ..             ...              ...            ...           ...
# 562          45.41              105  Paid Shipping  Basic Seller
# 563         633.42             1868  Paid Shipping   Star Seller
# 564          52.22             3453  Free Shipping  Basic Seller
# 565          21.57             1267  Paid Shipping   Star Seller
# 566          55.00            16867  Free Shipping   Star Seller
#
#          Recommended  Rating
# 4    Not Recommended    4.87
# 5        Recommended    4.94
# 6    Not Recommended    4.87
# 7        Recommended    4.98
# 8    Not Recommended    4.87
# ..               ...     ...
# 562      Recommended    5.00
# 563  Not Recommended    4.85
# 564      Recommended    4.91
# 565      Recommended    4.96
# 566      Recommended    4.83
#
# [517 rows x 9 columns]

# %%
# Assuming df is your DataFrame
df = df.drop_duplicates()
df
# Out:
#       Shop ID                                               Name   Price  \
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...   78.00
# 5    16050399  Historic eighteenth century shoes, 18th centur...  170.28
# 6    34365344  Barefoot Women Boot | Brown Leather Boot | Ear...  110.50
# 7     5774162                     Women's Middle English - OLIVE  216.00
# 8    34365344  Earth Shoe | Barefoot Sandale Women | Sandals ...   78.00
# ..        ...                                                ...     ...
# 562  22321483  Baby crawling shoes Mocca Leo dark blue with l...   45.41
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...  110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...   52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...   21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...   55.00
#
#      OriginalPrice  NumberOfReviews     ShipStatus    StarSeller  \
# 4           550.80             2419  Free Shipping   Star Seller
# 5           170.28             1031  Paid Shipping   Star Seller
# 6           780.30             2419  Free Shipping   Star Seller
# 7           216.00              533  Free Shipping  Basic Seller
# 8           550.80             2419  Free Shipping   Star Seller
# ..             ...              ...            ...           ...
# 562          45.41              105  Paid Shipping  Basic Seller
# 563         633.42             1868  Paid Shipping   Star Seller
# 564          52.22             3453  Free Shipping  Basic Seller
# 565          21.57             1267  Paid Shipping   Star Seller
# 566          55.00            16867  Free Shipping   Star Seller
#
#          Recommended  Rating
# 4    Not Recommended    4.87
# 5        Recommended    4.94
# 6    Not Recommended    4.87
# 7        Recommended    4.98
# 8    Not Recommended    4.87
# ..               ...     ...
# 562      Recommended    5.00
# 563  Not Recommended    4.85
# 564      Recommended    4.91
# 565      Recommended    4.96
# 566      Recommended    4.83
#
# [517 rows x 9 columns]

# %%
# Create a copy of the DataFrame
df = df.copy()

# Rename columns
column_mapping = {
    'Shop ID' : 'Shop ID',
    'Name': 'Name',
    'Price': 'Prices (RM)',
    'OriginalPrice': 'Original Price (RM)',
    'NumberOfReviews': 'Number of Reviews',
    'ShipStatus': 'Shipping Status',
    'StarSeller': 'Rank Seller',
    'Recommended': 'Recommended',
    'Rating': 'Rating'
}

df.rename(columns=column_mapping, inplace=True)

# Display the updated DataFrame
df
# Out:
#       Shop ID                                               Name  Prices (RM)  \
# 4    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...        78.00
# 5    16050399  Historic eighteenth century shoes, 18th centur...       170.28
# 6    34365344  Barefoot Women Boot | Brown Leather Boot | Ear...       110.50
# 7     5774162                     Women's Middle English - OLIVE       216.00
# 8    34365344  Earth Shoe | Barefoot Sandale Women | Sandals ...        78.00
# ..        ...                                                ...          ...
# 562  22321483  Baby crawling shoes Mocca Leo dark blue with l...        45.41
# 563   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...       110.40
# 564   5286176  OOAK kids slippers kittens, gift for cat lover...        52.22
# 565  11666639  Baby pure merino wool booties, baby first hand...        21.57
# 566   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...        55.00
#
#      Original Price (RM)  Number of Reviews Shipping Status   Rank Seller  \
# 4                 550.80               2419   Free Shipping   Star Seller
# 5                 170.28               1031   Paid Shipping   Star Seller
# 6                 780.30               2419   Free Shipping   Star Seller
# 7                 216.00                533   Free Shipping  Basic Seller
# 8                 550.80               2419   Free Shipping   Star Seller
# ..                   ...                ...             ...           ...
# 562                45.41                105   Paid Shipping  Basic Seller
# 563               633.42               1868   Paid Shipping   Star Seller
# 564                52.22               3453   Free Shipping  Basic Seller
# 565                21.57               1267   Paid Shipping   Star Seller
# 566                55.00              16867   Free Shipping   Star Seller
#
#          Recommended  Rating
# 4    Not Recommended    4.87
# 5        Recommended    4.94
# 6    Not Recommended    4.87
# 7        Recommended    4.98
# 8    Not Recommended    4.87
# ..               ...     ...
# 562      Recommended    5.00
# 563  Not Recommended    4.85
# 564      Recommended    4.91
# 565      Recommended    4.96
# 566      Recommended    4.83
#
# [517 rows x 9 columns]

# %%
# Save to CSV after cleaning
df.to_csv("shoes_etsy_clean.csv", index=False)

# %%
df = pd.read_csv('shoes_etsy_clean.csv')

# Check for presences of null value after cleaning
df.isna().any()
# Out:
# Shop ID                False
# Name                   False
# Prices (RM)            False
# Original Price (RM)    False
# Number of Reviews      False
# Shipping Status        False
# Rank Seller            False
# Recommended            False
# Rating                 False
# dtype: bool

# %% [markdown]
# ## **8. PERFORM DATA VISUALISATION**

# %%
# Function to remove outlier
def remove_outlier(data, column):
  Q1 = data[column].quantile(0.25)
  Q3 = data[column].quantile(0.75)
  IQR = Q3 - Q1

  # Upper bound
  upper = data[column] >= (Q3+1.5*IQR)

  # Lower bound
  lower = data[column] <= (Q1-1.5*IQR)

  # Remove the outlier
  data[column]=np.where(upper, (Q3+1.5*IQR), np.where(lower, (Q1-1.5*IQR), data[column]))

  return data

# %%
# import data
df = pd.read_csv('shoes_etsy_clean.csv')

# %% [markdown]
# ### **PRICE (RM) ATTRIBUTE**

# %%
# Creating histogram for 'Price' attribute
plt.figure(figsize=(20,6))
sns.histplot(data=df, x='Prices (RM)', kde=True, bins=30)

plt.title('Histogram of Product Prices (RM)')
plt.show()

# %%
# Describe the data using maximum and minimum functions
max_value = df['Prices (RM)'].max()
min_value = df['Prices (RM)'].min()
data_description = df['Prices (RM)'].describe()


print(f"Maximum value of {'Prices (RM)'}: {max_value}")
print(f"Minimum value of {'Prices (RM)'}: {min_value}")
print("\nData Description:")
print(data_description)
# Out:
# Maximum value of Prices (RM): 398.0
# Minimum value of Prices (RM): 2.65
#
# Data Description:
# count    517.000000
# mean     113.499149
# std       73.698114
# min        2.650000
# 25%       61.300000
# 50%       93.600000
# 75%      153.480000
# max      398.000000
# Name: Prices (RM), dtype: float64

# %%
# Before removing outlier
plt.figure(figsize=(20,6))
plot = sns.boxplot(x=df['Prices (RM)'],
                    width=0.2,
                    color="lightyellow")

plot.set_xlabel("Prices (RM)",
                fontsize=8, weight='bold')

plt.title('Boxplot of Prices (RM) Before Removing Outliers', fontsize=10)

plot.tick_params(labelsize=10)

# %%
remove_outlier(df, 'Prices (RM)')
# Out:
#       Shop ID                                               Name  Prices (RM)  \
# 0    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...        78.00
# 1    16050399  Historic eighteenth century shoes, 18th centur...       170.28
# 2    34365344  Barefoot Women Boot | Brown Leather Boot | Ear...       110.50
# 3     5774162                     Women's Middle English - OLIVE       216.00
# 4    34365344  Earth Shoe | Barefoot Sandale Women | Sandals ...        78.00
# ..        ...                                                ...          ...
# 512  22321483  Baby crawling shoes Mocca Leo dark blue with l...        45.41
# 513   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...       110.40
# 514   5286176  OOAK kids slippers kittens, gift for cat lover...        52.22
# 515  11666639  Baby pure merino wool booties, baby first hand...        21.57
# 516   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...        55.00
#
#      Original Price (RM)  Number of Reviews Shipping Status   Rank Seller  \
# 0                 550.80               2419   Free Shipping   Star Seller
# 1                 170.28               1031   Paid Shipping   Star Seller
# 2                 780.30               2419   Free Shipping   Star Seller
# 3                 216.00                533   Free Shipping  Basic Seller
# 4                 550.80               2419   Free Shipping   Star Seller
# ..                   ...                ...             ...           ...
# 512                45.41                105   Paid Shipping  Basic Seller
# 513               633.42               1868   Paid Shipping   Star Seller
# 514                52.22               3453   Free Shipping  Basic Seller
# 515                21.57               1267   Paid Shipping   Star Seller
# 516                55.00              16867   Free Shipping   Star Seller
#
#          Recommended  Rating
# 0    Not Recommended    4.87
# 1        Recommended    4.94
# 2    Not Recommended    4.87
# 3        Recommended    4.98
# 4    Not Recommended    4.87
# ..               ...     ...
# 512      Recommended    5.00
# 513  Not Recommended    4.85
# 514      Recommended    4.91
# 515      Recommended    4.96
# 516      Recommended    4.83
#
# [517 rows x 9 columns]

# %%
# After removing outlier
plt.figure(figsize=(20,6))
plot = sns.boxplot(x=df['Prices (RM)'],
                    width=0.2,
                    color="lightyellow")

plot.set_xlabel("Prices (RM)",
                fontsize=10, weight='bold')

plt.title('Boxplot of Prices (RM) After Removing Outliers', fontsize=10)

plot.tick_params(labelsize=10)

# %%
df['Prices (RM)'] = df['Prices (RM)'].round(decimals = 2)
df
# Out:
#       Shop ID                                               Name  Prices (RM)  \
# 0    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...        78.00
# 1    16050399  Historic eighteenth century shoes, 18th centur...       170.28
# 2    34365344  Barefoot Women Boot | Brown Leather Boot | Ear...       110.50
# 3     5774162                     Women's Middle English - OLIVE       216.00
# 4    34365344  Earth Shoe | Barefoot Sandale Women | Sandals ...        78.00
# ..        ...                                                ...          ...
# 512  22321483  Baby crawling shoes Mocca Leo dark blue with l...        45.41
# 513   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...       110.40
# 514   5286176  OOAK kids slippers kittens, gift for cat lover...        52.22
# 515  11666639  Baby pure merino wool booties, baby first hand...        21.57
# 516   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...        55.00
#
#      Original Price (RM)  Number of Reviews Shipping Status   Rank Seller  \
# 0                 550.80               2419   Free Shipping   Star Seller
# 1                 170.28               1031   Paid Shipping   Star Seller
# 2                 780.30               2419   Free Shipping   Star Seller
# 3                 216.00                533   Free Shipping  Basic Seller
# 4                 550.80               2419   Free Shipping   Star Seller
# ..                   ...                ...             ...           ...
# 512                45.41                105   Paid Shipping  Basic Seller
# 513               633.42               1868   Paid Shipping   Star Seller
# 514                52.22               3453   Free Shipping  Basic Seller
# 515                21.57               1267   Paid Shipping   Star Seller
# 516                55.00              16867   Free Shipping   Star Seller
#
#          Recommended  Rating
# 0    Not Recommended    4.87
# 1        Recommended    4.94
# 2    Not Recommended    4.87
# 3        Recommended    4.98
# 4    Not Recommended    4.87
# ..               ...     ...
# 512      Recommended    5.00
# 513  Not Recommended    4.85
# 514      Recommended    4.91
# 515      Recommended    4.96
# 516      Recommended    4.83
#
# [517 rows x 9 columns]

# %% [markdown]
# ### **ORIGINAL PRICES (RM)**

# %%
# Creating histogram for 'Original Price' attribute
plt.figure(figsize=(20,6))
sns.histplot(data=df, x='Original Price (RM)', kde=True, bins=30)
plt.title('Histogram of Product Original Price (RM)')
plt.show()

# %%
# Describe the data using maximum and minimum functions
max_value = df['Original Price (RM)'].max()
min_value = df['Original Price (RM)'].min()
data_description = df['Original Price (RM)'].describe()


print(f"Maximum value of {'Original Price (RM)'}: {max_value}")
print(f"Minimum value of {'Original Price (RM)'}: {min_value}")
print("\nData Description:")
print(data_description)
# Out:
# Maximum value of Original Price (RM): 2094.65
# Minimum value of Original Price (RM): 2.65
#
# Data Description:
# count     517.000000
# mean      343.648627
# std       396.859952
# min         2.650000
# 25%        71.990000
# 50%       145.000000
# 75%       547.130000
# max      2094.650000
# Name: Original Price (RM), dtype: float64

# %%
# Before removing outlier
plt.figure(figsize=(20,6))
plot = sns.boxplot(x=df['Original Price (RM)'],
                    width=0.2,
                    color="lightgreen")

plot.set_xlabel("Original Price (RM)",
                fontsize=8, weight='bold')

plt.title('Boxplot of Original Price (RM) Before Removing Outliers', fontsize=10)

plot.tick_params(labelsize=10)

# %%
remove_outlier(df, 'Original Price (RM)')
# Out:
#       Shop ID                                               Name  Prices (RM)  \
# 0    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...        78.00
# 1    16050399  Historic eighteenth century shoes, 18th centur...       170.28
# 2    34365344  Barefoot Women Boot | Brown Leather Boot | Ear...       110.50
# 3     5774162                     Women's Middle English - OLIVE       216.00
# 4    34365344  Earth Shoe | Barefoot Sandale Women | Sandals ...        78.00
# ..        ...                                                ...          ...
# 512  22321483  Baby crawling shoes Mocca Leo dark blue with l...        45.41
# 513   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...       110.40
# 514   5286176  OOAK kids slippers kittens, gift for cat lover...        52.22
# 515  11666639  Baby pure merino wool booties, baby first hand...        21.57
# 516   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...        55.00
#
#      Original Price (RM)  Number of Reviews Shipping Status   Rank Seller  \
# 0                 550.80               2419   Free Shipping   Star Seller
# 1                 170.28               1031   Paid Shipping   Star Seller
# 2                 780.30               2419   Free Shipping   Star Seller
# 3                 216.00                533   Free Shipping  Basic Seller
# 4                 550.80               2419   Free Shipping   Star Seller
# ..                   ...                ...             ...           ...
# 512                45.41                105   Paid Shipping  Basic Seller
# 513               633.42               1868   Paid Shipping   Star Seller
# 514                52.22               3453   Free Shipping  Basic Seller
# 515                21.57               1267   Paid Shipping   Star Seller
# 516                55.00              16867   Free Shipping   Star Seller
#
#          Recommended  Rating
# 0    Not Recommended    4.87
# 1        Recommended    4.94
# 2    Not Recommended    4.87
# 3        Recommended    4.98
# 4    Not Recommended    4.87
# ..               ...     ...
# 512      Recommended    5.00
# 513  Not Recommended    4.85
# 514      Recommended    4.91
# 515      Recommended    4.96
# 516      Recommended    4.83
#
# [517 rows x 9 columns]

# %%
# After removing outlier
plt.figure(figsize=(20,6))
plot = sns.boxplot(x=df['Original Price (RM)'],
                    width=0.2,
                    color="lightgreen")

plot.set_xlabel("Original Price (RM)",
                fontsize=10, weight='bold')

plt.title('Boxplot of Original Price (RM) After Removing Outliers', fontsize=10)

plot.tick_params(labelsize=10)

# %%
df['Original Price (RM)'] = df['Original Price (RM)'].round(decimals = 2)
df
# Out:
#       Shop ID                                               Name  Prices (RM)  \
# 0    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...        78.00
# 1    16050399  Historic eighteenth century shoes, 18th centur...       170.28
# 2    34365344  Barefoot Women Boot | Brown Leather Boot | Ear...       110.50
# 3     5774162                     Women's Middle English - OLIVE       216.00
# 4    34365344  Earth Shoe | Barefoot Sandale Women | Sandals ...        78.00
# ..        ...                                                ...          ...
# 512  22321483  Baby crawling shoes Mocca Leo dark blue with l...        45.41
# 513   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...       110.40
# 514   5286176  OOAK kids slippers kittens, gift for cat lover...        52.22
# 515  11666639  Baby pure merino wool booties, baby first hand...        21.57
# 516   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...        55.00
#
#      Original Price (RM)  Number of Reviews Shipping Status   Rank Seller  \
# 0                 550.80               2419   Free Shipping   Star Seller
# 1                 170.28               1031   Paid Shipping   Star Seller
# 2                 780.30               2419   Free Shipping   Star Seller
# 3                 216.00                533   Free Shipping  Basic Seller
# 4                 550.80               2419   Free Shipping   Star Seller
# ..                   ...                ...             ...           ...
# 512                45.41                105   Paid Shipping  Basic Seller
# 513               633.42               1868   Paid Shipping   Star Seller
# 514                52.22               3453   Free Shipping  Basic Seller
# 515                21.57               1267   Paid Shipping   Star Seller
# 516                55.00              16867   Free Shipping   Star Seller
#
#          Recommended  Rating
# 0    Not Recommended    4.87
# 1        Recommended    4.94
# 2    Not Recommended    4.87
# 3        Recommended    4.98
# 4    Not Recommended    4.87
# ..               ...     ...
# 512      Recommended    5.00
# 513  Not Recommended    4.85
# 514      Recommended    4.91
# 515      Recommended    4.96
# 516      Recommended    4.83
#
# [517 rows x 9 columns]

# %% [markdown]
# ### **NUMBER OF REVIEWS ATTRIBUTE**

# %%
# Creating histogram for 'Number Of Reviews' attribute
plt.figure(figsize=(20,6))
sns.histplot(data=df, x='Number of Reviews', kde=True, bins=30)
plt.title('Histogram of Number of Reviews')
plt.show()

# %%
# Describe the data using maximum and minimum functions
max_value = df['Number of Reviews'].max()
min_value = df['Number of Reviews'].min()
data_description = df['Number of Reviews'].describe()


print(f"Maximum value of {'Number of Reviews'}: {max_value}")
print(f"Minimum value of {'Number of Reviews'}: {min_value}")
print("\nData Description:")
print(data_description)
# Out:
# Maximum value of Number of Reviews: 25819
# Minimum value of Number of Reviews: 5
#
# Data Description:
# count      517.000000
# mean      3120.235977
# std       4661.407403
# min          5.000000
# 25%        526.000000
# 50%       1782.000000
# 75%       3306.000000
# max      25819.000000
# Name: Number of Reviews, dtype: float64

# %%
# Before removing outlier
plt.figure(figsize=(20,6))
plot = sns.boxplot(x=df['Number of Reviews'],
                    width=0.2,
                    color="lightyellow")

plot.set_xlabel("Number of Reviews",
                fontsize=8, weight='bold')

plt.title('Boxplot of Number of Reviews Before Removing Outliers', fontsize=10)

plot.tick_params(labelsize=10)

# %%
remove_outlier(df,'Number of Reviews')
# Out:
#       Shop ID                                               Name  Prices (RM)  \
# 0    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...        78.00
# 1    16050399  Historic eighteenth century shoes, 18th centur...       170.28
# 2    34365344  Barefoot Women Boot | Brown Leather Boot | Ear...       110.50
# 3     5774162                     Women's Middle English - OLIVE       216.00
# 4    34365344  Earth Shoe | Barefoot Sandale Women | Sandals ...        78.00
# ..        ...                                                ...          ...
# 512  22321483  Baby crawling shoes Mocca Leo dark blue with l...        45.41
# 513   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...       110.40
# 514   5286176  OOAK kids slippers kittens, gift for cat lover...        52.22
# 515  11666639  Baby pure merino wool booties, baby first hand...        21.57
# 516   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...        55.00
#
#      Original Price (RM)  Number of Reviews Shipping Status   Rank Seller  \
# 0                 550.80             2419.0   Free Shipping   Star Seller
# 1                 170.28             1031.0   Paid Shipping   Star Seller
# 2                 780.30             2419.0   Free Shipping   Star Seller
# 3                 216.00              533.0   Free Shipping  Basic Seller
# 4                 550.80             2419.0   Free Shipping   Star Seller
# ..                   ...                ...             ...           ...
# 512                45.41              105.0   Paid Shipping  Basic Seller
# 513               633.42             1868.0   Paid Shipping   Star Seller
# 514                52.22             3453.0   Free Shipping  Basic Seller
# 515                21.57             1267.0   Paid Shipping   Star Seller
# 516                55.00             7476.0   Free Shipping   Star Seller
#
#          Recommended  Rating
# 0    Not Recommended    4.87
# 1        Recommended    4.94
# 2    Not Recommended    4.87
# 3        Recommended    4.98
# 4    Not Recommended    4.87
# ..               ...     ...
# 512      Recommended    5.00
# 513  Not Recommended    4.85
# 514      Recommended    4.91
# 515      Recommended    4.96
# 516      Recommended    4.83
#
# [517 rows x 9 columns]

# %%
# After removing outlier
plt.figure(figsize=(20,6))
plot = sns.boxplot(x=df['Number of Reviews'],
                    width=0.2,
                    color="lightyellow")

plot.set_xlabel("Number of Reviews",
                fontsize=10, weight='bold')

plt.title('Boxplot of Number of Reviews After Removing Outliers', fontsize=10)

plot.tick_params(labelsize=10)

# %%
df['Number of Reviews'] = df['Number of Reviews'].round(decimals = 2).astype(int)
df
# Out:
#       Shop ID                                               Name  Prices (RM)  \
# 0    34365344  Earth Shoe | Grounding Shoe | Barefoot Shoes W...        78.00
# 1    16050399  Historic eighteenth century shoes, 18th centur...       170.28
# 2    34365344  Barefoot Women Boot | Brown Leather Boot | Ear...       110.50
# 3     5774162                     Women's Middle English - OLIVE       216.00
# 4    34365344  Earth Shoe | Barefoot Sandale Women | Sandals ...        78.00
# ..        ...                                                ...          ...
# 512  22321483  Baby crawling shoes Mocca Leo dark blue with l...        45.41
# 513   7939301  Pink Ankle-Strap Sandals, Leather Sandals, Pin...       110.40
# 514   5286176  OOAK kids slippers kittens, gift for cat lover...        52.22
# 515  11666639  Baby pure merino wool booties, baby first hand...        21.57
# 516   6691067  SOFT GOLD Fine Glitter Maryjane with Fine Glit...        55.00
#
#      Original Price (RM)  Number of Reviews Shipping Status   Rank Seller  \
# 0                 550.80               2419   Free Shipping   Star Seller
# 1                 170.28               1031   Paid Shipping   Star Seller
# 2                 780.30               2419   Free Shipping   Star Seller
# 3                 216.00                533   Free Shipping  Basic Seller
# 4                 550.80               2419   Free Shipping   Star Seller
# ..                   ...                ...             ...           ...
# 512                45.41                105   Paid Shipping  Basic Seller
# 513               633.42               1868   Paid Shipping   Star Seller
# 514                52.22               3453   Free Shipping  Basic Seller
# 515                21.57               1267   Paid Shipping   Star Seller
# 516                55.00               7476   Free Shipping   Star Seller
#
#          Recommended  Rating
# 0    Not Recommended    4.87
# 1        Recommended    4.94
# 2    Not Recommended    4.87
# 3        Recommended    4.98
# 4    Not Recommended    4.87
# ..               ...     ...
# 512      Recommended    5.00
# 513  Not Recommended    4.85
# 514      Recommended    4.91
# 515      Recommended    4.96
# 516      Recommended    4.83
#
# [517 rows x 9 columns]

# %% [markdown]
# ### **SCATTERPLOT BETWEEN PRICE AND NUMBER OF REVIEWS**

# %%
# Assuming df is your DataFrame
sns.set(style="whitegrid")

# Scatterplot with regression line
plt.figure(figsize=(20, 6))
scatter_plot = sns.regplot(x='Prices (RM)', y='Number of Reviews', data=df, scatter_kws={'s': 20}, line_kws={'color': 'red'})
scatter_plot.set(title='Scatterplot with Regression Line', xlabel='Prices (RM)', ylabel='Number of Reviews')

plt.show()

# %% [markdown]
# ### **SCATTERPLOT BETWEEN PRICE AND RATING**

# %%
# Assuming df is your DataFrame
sns.set(style="whitegrid")

# Scatterplot with regression line
plt.figure(figsize=(20, 6))
scatter_plot = sns.regplot(x='Prices (RM)', y='Rating', data=df, scatter_kws={'s': 20}, line_kws={'color': 'red'})
scatter_plot.set(title='Scatterplot with Regression Line', xlabel='Prices (RM)', ylabel='Rating')

plt.show()

# %%
# Assuming df is your DataFrame
sns.set(style="whitegrid")

# Scatterplot with regression line
plt.figure(figsize=(20, 6))
scatter_plot = sns.regplot(x='Prices (RM)', y='Original Price (RM)', data=df, scatter_kws={'s': 20}, line_kws={'color': 'red'})
scatter_plot.set(title='Scatterplot with Regression Line', xlabel='Prices (RM)', ylabel='Original Price (RM)')

plt.show()

# %%
# Set the size of the individual plots
scatter_kws = {"s": 50}  # Adjust the size as needed

# Set the aspect ratio (width) of the individual plots
aspect_ratio = 3  # Adjust the aspect ratio as needed

sns.lmplot(x="Prices (RM)",
           y="Rating",
           hue="Recommended",
           data=df,
           ci=None,
           height=5,  # Controls the height of the facet grid
           aspect=aspect_ratio,  # Controls the aspect ratio (width)
           scatter_kws=scatter_kws).set(title=" Scatterplot for Prices (RM) VS Rating According to Recommended")
